# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings
warnings.filterwarnings('ignore')

# %%
wwe=pd.read_csv("data.csv")

# %%
wwe
# Out:
#                  name  reign  days       date              event  \
# 0        Buddy Rogers      1    36  11-Apr-63         House show
# 1    Bruno Sammartino      1  2803  17-May-63         House show
# 2         Ivan Koloff      1    21  18-Jan-71         House show
# 3       Pedro Morales      1  1027   8-Feb-71         House show
# 4        Stan Stasiak      1     9   1-Dec-73         House show
# ..                ...    ...   ...        ...                ...
# 407       Becky Lynch      3    41   8-Apr-19    WrestleMania 35
# 408   Charlotte Flair      4     0  19-May-19  Money in the Bank
# 409            Bayley      1   140  19-May-19  Money in the Bank
# 410   Charlotte Flair      5     5   6-Oct-19     Hell in a Cell
# 411            Bayley      2   247  11-Oct-19          SmackDown
#
#                 location                           link  \
# 0       Washington, D.C.  /wiki/Buddy_Rogers_(wrestler)
# 1           New York, NY         /wiki/Bruno_Sammartino
# ...

# %%
wwe.describe()
# Out:
#             reign         days
# count  412.000000   412.000000
# mean     2.230583   136.475728
# std      1.847662   320.631967
# min      1.000000     0.000000
# 25%      1.000000    27.750000
# 50%      2.000000    69.000000
# 75%      3.000000   140.000000
# max     13.000000  3651.000000

# %%
q1=wwe["reign"].quantile(0.25)
q3=wwe["reign"].quantile(0.75)
print(q1)
print(q3)
# Out:
# 1.0
# 3.0

# %%
iqr = q3-q1
iqr
# Out:
# np.float64(2.0)

# %%
lower=q1-1.5*iqr
upper=q3+1.5*iqr
print(upper)
print(lower)
# Out:
# 6.0
# -2.0

# %%
outliers=wwe[((wwe['reign']<lower)|(wwe['reign']>upper))]
print(outliers)
# Out:
#               name  reign  days       date               event  \
# 69        The Rock      7    35  21-Jul-02           Vengeance
# 87        Triple H      7   210  27-Apr-08            Backlash
# 91        Triple H      8    70  15-Feb-09          No Way Out
# 101      John Cena      7    84  28-Mar-10   WrestleMania XXVI
# 105      John Cena      8    77   1-May-11       Extreme Rules
# 108      John Cena      9    20  25-Jul-11                 Raw
# 111      John Cena     10    14  18-Sep-11  Night of Champions
# 114       The Rock      8    70  27-Jan-13        Royal Rumble
# 115      John Cena     11   133   7-Apr-13     WrestleMania 29
# 117    Randy Orton      7    28  18-Aug-13          SummerSlam
# 119    Randy Orton      8   161  27-Oct-13      Hell in a Cell
# 121      John Cena     12    49  29-Jun-14   Money in the Bank
# 127       Triple H      9    70  24-Jan-16        Royal Rumble
# 132      John Cena     13    14  29-Jan-17        Royal Rumble
# ...

# %%
nooutliers=wwe[~((wwe['reign']<lower)|(wwe['reign']>upper))]
nooutliers
# Out:
#                  name  reign  days       date              event  \
# 0        Buddy Rogers      1    36  11-Apr-63         House show
# 1    Bruno Sammartino      1  2803  17-May-63         House show
# 2         Ivan Koloff      1    21  18-Jan-71         House show
# 3       Pedro Morales      1  1027   8-Feb-71         House show
# 4        Stan Stasiak      1     9   1-Dec-73         House show
# ..                ...    ...   ...        ...                ...
# 407       Becky Lynch      3    41   8-Apr-19    WrestleMania 35
# 408   Charlotte Flair      4     0  19-May-19  Money in the Bank
# 409            Bayley      1   140  19-May-19  Money in the Bank
# 410   Charlotte Flair      5     5   6-Oct-19     Hell in a Cell
# 411            Bayley      2   247  11-Oct-19          SmackDown
#
#                 location                           link  \
# 0       Washington, D.C.  /wiki/Buddy_Rogers_(wrestler)
# 1           New York, NY         /wiki/Bruno_Sammartino
# ...

# %%
plt.figure(figsize=(8,5))
sns.distplot(nooutliers['reign'])
plt.title("With outliers")
plt.show()

# %%
plt.figure(figsize=(8,5))
sns.distplot(outliers['reign'])
plt.title("With out outliers")
plt.show()
