# %% [markdown]
# # Pandas

# %%
import pandas as pd

# %%
pip install pandas
# Out:
# ...
# [notice] A new release of pip is available: 24.0 -> 24.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...

# %%
import pandas as pd

# %%
df=pd.read_csv("supermarket_sales.csv")
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 17 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Invoice ID               1000 non-null   object
#  1   Branch                   1000 non-null   object
#  2   City                     1000 non-null   object
#  3   Customer type            1000 non-null   object
#  4   Gender                   1000 non-null   object
#  5   Product line             1000 non-null   object
#  6   Unit price               1000 non-null   float64
#  7   Quantity                 1000 non-null   int64
#  8   Tax 5%                   1000 non-null   float64
#  9   Total                    1000 non-null   float64
#  10  Date                     1000 non-null   object
#  11  Time                     1000 non-null   object
#  12  Payment                  1000 non-null   object
#  13  cogs                     1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Invoice ID                 0
# Branch                     0
# City                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.describe(include="all")
# Out:
#          Invoice ID Branch    City Customer type  Gender         Product line  \
# count          1000   1000    1000          1000    1000                 1000
# unique         1000      3       3             2       2                    6
# top     750-67-8428      A  Yangon        Member  Female  Fashion accessories
# freq              1    340     340           501     501                  178
# mean            NaN    NaN     NaN           NaN     NaN                  NaN
# std             NaN    NaN     NaN           NaN     NaN                  NaN
# min             NaN    NaN     NaN           NaN     NaN                  NaN
# 25%             NaN    NaN     NaN           NaN     NaN                  NaN
# 50%             NaN    NaN     NaN           NaN     NaN                  NaN
# 75%             NaN    NaN     NaN           NaN     NaN                  NaN
# max             NaN    NaN     NaN           NaN     NaN                  NaN
#
# ...

# %%
df.columns
# Out:
# Index(['Invoice ID', 'Branch', 'City', 'Customer type', 'Gender',
#        'Product line', 'Unit price', 'Quantity', 'Tax 5%', 'Total', 'Date',
#        'Time', 'Payment', 'cogs', 'gross margin percentage', 'gross income',
#        'Rating'],
#       dtype='object')

# %%
df.drop("Invoice ID",axis=1)
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
df['City'].unique()
# Out:
# array(['Yangon', 'Naypyitaw', 'Mandalay'], dtype=object)

# %%
df.drop("Invoice ID",axis=1,inplace=True)

# %%
df
# Out:
#     Branch       City Customer type  Gender            Product line  \
# 0        A     Yangon        Member  Female       Health and beauty
# 1        C  Naypyitaw        Normal  Female  Electronic accessories
# 2        A     Yangon        Normal    Male      Home and lifestyle
# 3        A     Yangon        Member    Male       Health and beauty
# 4        A     Yangon        Normal    Male       Sports and travel
# ..     ...        ...           ...     ...                     ...
# 995      C  Naypyitaw        Normal    Male       Health and beauty
# 996      B   Mandalay        Normal  Female      Home and lifestyle
# 997      A     Yangon        Member    Male      Food and beverages
# 998      A     Yangon        Normal    Male      Home and lifestyle
# 999      A     Yangon        Member  Female     Fashion accessories
#
#      Unit price  Quantity   Tax 5%      Total       Date   Time      Payment  \
# ...

# %%
df.sort_values(by="Unit price",ascending=False)
# Out:
#     Branch       City Customer type  Gender         Product line  Unit price  \
# 983      C  Naypyitaw        Normal    Male    Health and beauty       99.96
# 122      B   Mandalay        Member    Male    Sports and travel       99.96
# 930      B   Mandalay        Normal    Male   Home and lifestyle       99.92
# 494      B   Mandalay        Normal    Male  Fashion accessories       99.89
# 283      A     Yangon        Member    Male    Health and beauty       99.83
# ..     ...        ...           ...     ...                  ...         ...
# 881      C  Naypyitaw        Member  Female  Fashion accessories       10.18
# 822      C  Naypyitaw        Member    Male    Sports and travel       10.17
# 784      C  Naypyitaw        Member  Female    Health and beauty       10.16
# 572      A     Yangon        Member    Male   Food and beverages       10.13
# 944      A     Yangon        Member    Male    Health and beauty       10.08
#
# ...

# %%
df[df["City"] == "Yangon"].head(5)
# Out:
#   Branch    City Customer type  Gender            Product line  Unit price  \
# 0      A  Yangon        Member  Female       Health and beauty       74.69
# 2      A  Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A  Yangon        Member    Male       Health and beauty       58.22
# 4      A  Yangon        Normal    Male       Sports and travel       86.31
# 6      A  Yangon        Member  Female  Electronic accessories       68.84
#
#    Quantity   Tax 5%     Total       Date   Time      Payment    cogs  \
# 0         7  26.1415  548.9715   1/5/2019  13:08      Ewallet  522.83
# 2         7  16.2155  340.5255   3/3/2019  13:23  Credit card  324.31
# 3         8  23.2880  489.0480  1/27/2019  20:33      Ewallet  465.76
# 4         7  30.2085  634.3785   2/8/2019  10:37      Ewallet  604.17
# 6         6  20.6520  433.6920  2/25/2019  14:36      Ewallet  413.04
#
#    gross margin percentage  gross income  Rating
# ...

# %%
df.rename({"City":"Site","Branch":"Item"},axis=1,inplace=True)
df
# Out:
#     Item       Site Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
# ..   ...        ...           ...     ...                     ...         ...
# 995    C  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996    B   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997    A     Yangon        Member    Male      Food and beverages       31.84
# 998    A     Yangon        Normal    Male      Home and lifestyle       65.82
# 999    A     Yangon        Member  Female     Fashion accessories       88.34
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 16 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Item                     1000 non-null   object
#  1   Site                     1000 non-null   object
#  2   Customer type            1000 non-null   object
#  3   Gender                   1000 non-null   object
#  4   Product line             1000 non-null   object
#  5   Unit price               1000 non-null   float64
#  6   Quantity                 1000 non-null   int64
#  7   Tax 5%                   1000 non-null   float64
#  8   Total                    1000 non-null   float64
#  9   Date                     1000 non-null   object
#  10  Time                     1000 non-null   object
#  11  Payment                  1000 non-null   object
#  12  cogs                     1000 non-null   float64
#  13  gross margin percentage  1000 non-null   float64
# ...

# %%
df.isnull().sum()
# Out:
# Item                       0
# Site                       0
# Customer type              0
# Gender                     0
# Product line               0
# Unit price                 0
# Quantity                   0
# Tax 5%                     0
# Total                      0
# Date                       0
# Time                       0
# Payment                    0
# cogs                       0
# gross margin percentage    0
# gross income               0
# Rating                     0
# dtype: int64

# %%
df.shape
# Out:
# (1000, 16)

# %%
df.isnull().sum()/df.shape[1]*100
# Out:
# Item                       0.0
# Site                       0.0
# Customer type              0.0
# Gender                     0.0
# Product line               0.0
# Unit price                 0.0
# Quantity                   0.0
# Tax 5%                     0.0
# Total                      0.0
# Date                       0.0
# Time                       0.0
# Payment                    0.0
# cogs                       0.0
# gross margin percentage    0.0
# gross income               0.0
# Rating                     0.0
# dtype: float64

# %%
print(df.columns)
# Out:
# Index(['Item', 'Site', 'Customer type', 'Gender', 'Product line', 'Unit price',
#        'Quantity', 'Tax 5%', 'Total', 'Date', 'Time', 'Payment', 'cogs',
#        'gross margin percentage', 'gross income', 'Rating'],
#       dtype='object')

# %%
df.columns = df.columns.str.strip()
df
# Out:
#     Item       Site Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
# ..   ...        ...           ...     ...                     ...         ...
# 995    C  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996    B   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997    A     Yangon        Member    Male      Food and beverages       31.84
# 998    A     Yangon        Normal    Male      Home and lifestyle       65.82
# 999    A     Yangon        Member  Female     Fashion accessories       88.34
#
# ...

# %%
round(df.isnull().sum()/df.shape[0]*100,0)
# Out:
# Item                       0.0
# Site                       0.0
# Customer type              0.0
# Gender                     0.0
# Product line               0.0
# Unit price                 0.0
# Quantity                   0.0
# Tax 5%                     0.0
# Total                      0.0
# Date                       0.0
# Time                       0.0
# Payment                    0.0
# cogs                       0.0
# gross margin percentage    0.0
# gross income               0.0
# Rating                     0.0
# dtype: float64

# %%
# import pandas as pd
# import numpy as np
# data = {'Kamesh': [1, 2, np.nan, 4], 'Alan': [5, np.nan, np.nan, 8], 'Kamini': [10,11,12,np.nan]}
# df = pd.DataFrame(data)
# df

# %%
df.isnull()
# Out:
#    Kamesh   Alan  Kamini
# 0   False  False   False
# 1   False   True   False
# 2    True   True   False
# 3   False  False    True

# %%
df["Alan"].fillna(1)

# %%
df["Kamini"].fillna(1,inplace=True)
# Out:
# C:\Users\SYS 2\AppData\Local\Temp\ipykernel_7072\2125578365.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["Kamini"].fillna(1,inplace=True)

# %%
df
# Out:
#    Kamesh  Alan  Kamini
# 0     1.0   5.0    10.0
# 1     2.0   NaN    11.0
# 2     NaN   NaN    12.0
# 3     4.0   8.0     1.0

# %%
df["Alan"].replace({1.0:2})
# Out:
# 0    5.0
# 1    NaN
# 2    NaN
# 3    8.0
# Name: Alan, dtype: float64

# %%
df["Site"].value_counts().plot(kind="pie")
# Out:
# <Axes: ylabel='count'>

# %%
dff=pd.DataFrame({"name":["alan",np.nan,"kamini"],"age":["21",'22','23'],"place":["pondy",np.nan,"france"]})

# %%
dff
# Out:
#      name age   place
# 0    alan  21   pondy
# 1     NaN  22     NaN
# 2  kamini  23  france

# %%
dff["name"].fillna("kamesh",inplace=True)

# %%
dff
# Out:
#      name age   place
# 0    alan  21   pondy
# 1  kamesh  22     NaN
# 2  kamini  23  france

# %%
dff["place"].dropna()
# Out:
# 0     pondy
# 2    france
# Name: place, dtype: object

# %%
dff.dropna(subset=["place"],inplace=True)

# %%
dff
# Out:
#      name age   place
# 0    alan  21   pondy
# 2  kamini  23  france

# %%
dff.drop("place",axis=1,inplace=True)

# %%
dff
# Out:
#      name age
# 0    alan  21
# 2  kamini  23

# %%
df
# Out:
#     Item       Site Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 1      C  Naypyitaw        Normal  Female  Electronic accessories       15.28
# 2      A     Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A     Yangon        Member    Male       Health and beauty       58.22
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
# ..   ...        ...           ...     ...                     ...         ...
# 995    C  Naypyitaw        Normal    Male       Health and beauty       40.35
# 996    B   Mandalay        Normal  Female      Home and lifestyle       97.38
# 997    A     Yangon        Member    Male      Food and beverages       31.84
# 998    A     Yangon        Normal    Male      Home and lifestyle       65.82
# 999    A     Yangon        Member  Female     Fashion accessories       88.34
#
# ...

# %%
df[df["Item"]=="A"]
# Out:
#     Item    Site Customer type  Gender            Product line  Unit price  \
# 0      A  Yangon        Member  Female       Health and beauty       74.69
# 2      A  Yangon        Normal    Male      Home and lifestyle       46.33
# 3      A  Yangon        Member    Male       Health and beauty       58.22
# 4      A  Yangon        Normal    Male       Sports and travel       86.31
# 6      A  Yangon        Member  Female  Electronic accessories       68.84
# ..   ...     ...           ...     ...                     ...         ...
# 990    A  Yangon        Normal  Female      Food and beverages       56.56
# 992    A  Yangon        Normal    Male  Electronic accessories       58.03
# 997    A  Yangon        Member    Male      Food and beverages       31.84
# 998    A  Yangon        Normal    Male      Home and lifestyle       65.82
# 999    A  Yangon        Member  Female     Fashion accessories       88.34
#
# ...

# %%
df[df["Total"]>500]
# Out:
#     Item       Site Customer type  Gender            Product line  Unit price  \
# 0      A     Yangon        Member  Female       Health and beauty       74.69
# 4      A     Yangon        Normal    Male       Sports and travel       86.31
# 5      C  Naypyitaw        Normal    Male  Electronic accessories       85.39
# 7      C  Naypyitaw        Normal  Female      Home and lifestyle       73.56
# 14     A     Yangon        Normal  Female       Health and beauty       71.38
# ..   ...        ...           ...     ...                     ...         ...
# 988    C  Naypyitaw        Member    Male  Electronic accessories       82.34
# 989    B   Mandalay        Member    Male       Health and beauty       75.37
# 991    B   Mandalay        Normal  Female       Sports and travel       76.60
# 996    B   Mandalay        Normal  Female      Home and lifestyle       97.38
# 999    A     Yangon        Member  Female     Fashion accessories       88.34
#
# ...
